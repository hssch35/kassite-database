# %%
wort_1 = {"transkription": "mali", "bedeutung": "Mensch", "wortart": "Substantiv" "sicherheit" : "belegt"}
print("Erster Datenbank-Eintrag:")
print(f"Kassitisch: {wort_1['transkription']} -> Deutsch: {wort_1['bedeutung']}")
